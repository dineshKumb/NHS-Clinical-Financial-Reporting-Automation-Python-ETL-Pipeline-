# %% [markdown]
# # Using this code you can trigger this pipeline
#
# ### 1. verification if all paths are present as per requirement if not then create those paths
# ### 2. Loading financial data
# ### 3. Pre-processing the loaded data
# ### 4. Transformation
# ### 5. Saving final report with required KPIs

# %% [markdown]
# ## Path verification and Creation if required

# %%
# %run Verification.ipynb
# %run Copy_files_in_Bronze_layer.ipynb
# %run Separate_and_combined.ipynb
# %run Final_Merges.ipynb
# %run Create_Report.ipynb
# Out:
# Created folder: C:\Users\Gauri\Documents\End to End Reporting Project\Working environment\Person_1
#   Created subfolder: C:\Users\Gauri\Documents\End to End Reporting Project\Working environment\Person_1\Bronze
#   Created subfolder: C:\Users\Gauri\Documents\End to End Reporting Project\Working environment\Person_1\Silver
#   Created subfolder: C:\Users\Gauri\Documents\End to End Reporting Project\Working environment\Person_1\Gold
# Created folder: C:\Users\Gauri\Documents\End to End Reporting Project\Working environment\Person_2
#   Created subfolder: C:\Users\Gauri\Documents\End to End Reporting Project\Working environment\Person_2\Bronze
#   Created subfolder: C:\Users\Gauri\Documents\End to End Reporting Project\Working environment\Person_2\Silver
#   Created subfolder: C:\Users\Gauri\Documents\End to End Reporting Project\Working environment\Person_2\Gold
# Created folder: C:\Users\Gauri\Documents\End to End Reporting Project\Working environment\Person_3
# ...
